# %%
import pandas as pd
file_path = "/Users/rajendraacharya/Desktop/Python/AI:ML/AI-ML-training/crop yield data sheet.xlsx"
train_data = pd.read_excel(file_path)
print(train_data)
# Out:
#      Rain Fall (mm)  Fertilizer Temperatue  Nitrogen (N)  Phosphorus (P)  \
# 0            1230.0        80.0         28          80.0            24.0
# 1             480.0        60.0         36          70.0            20.0
# 2            1250.0        75.0         29          78.0            22.0
# 3             450.0        65.0         35          70.0            19.0
# 4            1200.0        80.0         27          79.0            22.0
# ..              ...         ...        ...           ...             ...
# 104             NaN         NaN        NaN           NaN             NaN
# 105             NaN         NaN        NaN           NaN             NaN
# 106             NaN         NaN        NaN           NaN             NaN
# 107             NaN         NaN        NaN           NaN             NaN
# 108             NaN         NaN          :           NaN             NaN
#
#      Potassium (K)  Yeild (Q/acre)
# 0             20.0            12.0
# 1             18.0             8.0
# 2             19.0            11.0
# 3             18.0             9.0
# 4             19.0            11.0
# ..             ...             ...
# 104            NaN             NaN
# 105            NaN             NaN
# 106            NaN             NaN
# 107            NaN             NaN
# 108            NaN             NaN
#
# [109 rows x 7 columns]

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in ./env/lib/python3.9/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in ./env/lib/python3.9/site-packages (from openpyxl) (1.1.0)
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/Users/rajendraacharya/Desktop/Python/AI:ML/AI-ML-training/env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
train_data.describe()
# Out:
#        Rain Fall (mm)  Fertilizer  Nitrogen (N)  Phosphorus (P)  \
# count       99.000000   99.000000     99.000000       99.000000
# mean       849.797980   67.808081     70.737374       21.131313
# std        400.042676   10.028202      6.677079        1.951695
# min        400.000000   50.000000     59.000000       18.000000
# 25%        450.000000   60.000000     65.000000       19.500000
# 50%       1150.000000   70.000000     71.000000       21.000000
# 75%       1237.500000   77.000000     77.000000       23.000000
# max       1300.000000   80.000000     80.000000       25.000000
#
#        Potassium (K)  Yeild (Q/acre)
# count      99.000000       99.000000
# mean       18.060606        9.050505
# std         1.817254        1.965902
# min        15.000000        5.500000
# 25%        16.000000        7.000000
# 50%        19.000000        9.000000
# 75%        19.000000       11.000000
# max        22.000000       12.000000

# %%
train_data.tail()
# Out:
#      Rain Fall (mm)  Fertilizer Temperatue  Nitrogen (N)  Phosphorus (P)  \
# 104             NaN         NaN        NaN           NaN             NaN
# 105             NaN         NaN        NaN           NaN             NaN
# 106             NaN         NaN        NaN           NaN             NaN
# 107             NaN         NaN        NaN           NaN             NaN
# 108             NaN         NaN          :           NaN             NaN
#
#      Potassium (K)  Yeild (Q/acre)
# 104            NaN             NaN
# 105            NaN             NaN
# 106            NaN             NaN
# 107            NaN             NaN
# 108            NaN             NaN

# %%
pd.set_option('display.max_rows', 10)

# %%
train_data.tail(12)
# Out:
#      Rain Fall (mm)  Fertilizer Temperatue  Nitrogen (N)  Phosphorus (P)  \
# 97            480.0        65.0         36          68.0            21.0
# 98           1230.0        80.0         28          80.0            24.0
# 99              NaN         NaN        NaN           NaN             NaN
# 100             NaN         NaN        NaN           NaN             NaN
# 101             NaN         NaN        NaN           NaN             NaN
# ..              ...         ...        ...           ...             ...
# 104             NaN         NaN        NaN           NaN             NaN
# 105             NaN         NaN        NaN           NaN             NaN
# 106             NaN         NaN        NaN           NaN             NaN
# 107             NaN         NaN        NaN           NaN             NaN
# 108             NaN         NaN          :           NaN             NaN
#
#      Potassium (K)  Yeild (Q/acre)
# 97            16.0             7.0
# 98            20.0            12.0
# 99             NaN             NaN
# 100            NaN             NaN
# 101            NaN             NaN
# ..             ...             ...
# 104            NaN             NaN
# 105            NaN             NaN
# 106            NaN             NaN
# 107            NaN             NaN
# 108            NaN             NaN
#
# [12 rows x 7 columns]

# %%
nan_count = train_data.isnull().sum(axis=1)

# %%
data = train_data.dropna()
data.tail(12)
# Out:
#     Rain Fall (mm)  Fertilizer Temperatue  Nitrogen (N)  Phosphorus (P)  \
# 87           475.0        60.0         39          70.0            20.0
# 88          1200.0        75.0         28          77.0            23.0
# 89           410.0        52.0         40          62.0            19.0
# 90          1225.0        75.0         28          75.0            23.0
# 91           460.0        60.0         39          60.0            20.0
# ..             ...         ...        ...           ...             ...
# 94          1250.0        77.0         28          78.0            23.0
# 95           425.0        60.0         39          65.0            19.0
# 96          1220.0        79.0         28          77.0            23.0
# 97           480.0        65.0         36          68.0            21.0
# 98          1230.0        80.0         28          80.0            24.0
#
#     Potassium (K)  Yeild (Q/acre)
# 87           17.0             8.0
# 88           19.0            11.0
# 89           16.0             6.5
# 90           20.0            11.0
# 91           16.0             7.0
# ..            ...             ...
# 94           20.0             9.0
# 95           17.0             6.5
# 96           21.0            10.5
# 97           16.0             7.0
# 98           20.0            12.0
#
# [12 rows x 7 columns]

# %%
train_data
# Out:
#      Rain Fall (mm)  Fertilizer Temperatue  Nitrogen (N)  Phosphorus (P)  \
# 0            1230.0        80.0         28          80.0            24.0
# 1             480.0        60.0         36          70.0            20.0
# 2            1250.0        75.0         29          78.0            22.0
# 3             450.0        65.0         35          70.0            19.0
# 4            1200.0        80.0         27          79.0            22.0
# ..              ...         ...        ...           ...             ...
# 104             NaN         NaN        NaN           NaN             NaN
# 105             NaN         NaN        NaN           NaN             NaN
# 106             NaN         NaN        NaN           NaN             NaN
# 107             NaN         NaN        NaN           NaN             NaN
# 108             NaN         NaN          :           NaN             NaN
#
#      Potassium (K)  Yeild (Q/acre)
# 0             20.0            12.0
# 1             18.0             8.0
# 2             19.0            11.0
# 3             18.0             9.0
# 4             19.0            11.0
# ..             ...             ...
# 104            NaN             NaN
# 105            NaN             NaN
# 106            NaN             NaN
# 107            NaN             NaN
# 108            NaN             NaN
#
# [109 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming train_data is your DataFrame
plt.figure(figsize=(8, 16))
sns.heatmap(train_data.isnull(), cbar=False, cmap='binary')
plt.show()

# %%
plt.figure(figsize=(8, 16))
sns.heatmap(data.isnull(), cbar=False, cmap='binary')
plt.show()

# %%
corr_matrix = data.corr()
corr_matrix['Yeild (Q/acre)']
# Out:
# Rain Fall (mm)    0.886721
# Fertilizer        0.833823
# Temperatue       -0.892425
# Nitrogen (N)      0.879056
# Phosphorus (P)    0.800094
# Potassium (K)     0.856010
# Yeild (Q/acre)    1.000000
# Name: Yeild (Q/acre), dtype: float64

# %%
plt.scatter(data['Rain Fall (mm)'],data['Yeild (Q/acre)'])
plt.title('Scatter plot')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
plt.boxplot(data['Rain Fall (mm)'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x12bd9dd00>,
#   <matplotlib.lines.Line2D at 0x12bd9dfa0>],
#  'caps': [<matplotlib.lines.Line2D at 0x12bdaf280>,
#   <matplotlib.lines.Line2D at 0x12bdaf520>],
#  'boxes': [<matplotlib.lines.Line2D at 0x12bd9db80>],
#  'medians': [<matplotlib.lines.Line2D at 0x12bdaf7c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x12bdafa60>],
#  'means': []}

# %%
plt.boxplot(data[""])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/Python/AI:ML/AI-ML-training/env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 plt.boxplot(data[""])
#
# File ~/Desktop/Python/AI:ML/AI-ML-training/env/lib/python3.9/site-packages/pandas/core/frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~/Desktop/Python/AI:ML/AI-ML-training/env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: ''

# %%
# Assuming 'data' is your DataFrame
plt.boxplot(data['Fertilizer'],data['Nitrogen'])
plt.show()

# %%
plt.figure(figsize=(10, 1))
plt.boxplot([data[column] for column in data])
plt.title('Boxplots for Different Temperatures')
plt.ylabel('Temperature')
plt.show()

# %%
corr_matrix = data.corr()

# %%
corr_matrix
# Out:
#                 Rain Fall (mm)  Fertilizer  Temperatue  Nitrogen (N)  \
# Rain Fall (mm)        1.000000    0.890318   -0.967291      0.875808
# Fertilizer            0.890318    1.000000   -0.864742      0.909786
# Temperatue           -0.967291   -0.864742    1.000000     -0.846513
# Nitrogen (N)          0.875808    0.909786   -0.846513      1.000000
# Phosphorus (P)        0.776814    0.816710   -0.780556      0.778651
# Potassium (K)         0.810893    0.762152   -0.779570      0.808640
# Yeild (Q/acre)        0.886721    0.833823   -0.892425      0.879056
#
#                 Phosphorus (P)  Potassium (K)  Yeild (Q/acre)
# Rain Fall (mm)        0.776814       0.810893        0.886721
# Fertilizer            0.816710       0.762152        0.833823
# Temperatue           -0.780556      -0.779570       -0.892425
# Nitrogen (N)          0.778651       0.808640        0.879056
# Phosphorus (P)        1.000000       0.748642        0.800094
# Potassium (K)         0.748642       1.000000        0.856010
# Yeild (Q/acre)        0.800094       0.856010        1.000000

# %% [markdown]
# Feature algorithm:
